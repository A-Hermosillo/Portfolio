# %% [markdown]
# ## Ruteo Coppel 04-Ene-2022

# %% [markdown]
# ### Librerías

# %%
import warnings 
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import requests
from urllib.parse import urlencode

# %% [markdown]
# ### Lectura de Base de Datos

# %%
coppel = pd.DataFrame(pd.read_excel("Entregas_22_Actualizadas.xlsx"))

# %% [markdown]
# ### Análisis y Filtración

# %%
df = coppel[(coppel.fechaenrutada == "2022-01-04") & (coppel.Cedis == "Guadalajara")]
df
# Out:
#        Bodega        Cedis  factura  foliocontrol  tienda  \
# 19766   30007  Guadalajara   623230       7222827     800
# 19803   30007  Guadalajara   624114       7222844     800
# 19814   30007  Guadalajara   621388       7222831     800
# 19824   30007  Guadalajara   328622       7222842     396
# 19870   30007  Guadalajara   328613       7222839     396
# ...       ...          ...      ...           ...     ...
# 31189   30007  Guadalajara   591610       7222825     800
# 31192   30007  Guadalajara     2745       7222844    1150
# 31197   30007  Guadalajara   625743       7222819     800
# 31216   30007  Guadalajara    16048       7222830      86
# 31221   30007  Guadalajara   580507       7222837     800
#
#                      Unnamed: 5 fechaventa fechaenrutada  ruta  codigo  ...  \
# 19766  30007_623230_7222827_800 2022-01-03    2022-01-04     2  150223  ...
# 19803  30007_624114_7222844_800 2022-01-03    2022-01-04    36  361313  ...
# ...

# %%
df.isna().sum()
# Out:
# Bodega                0
# Cedis                 0
# factura               0
# foliocontrol          0
# tienda                0
# Unnamed: 5            0
# fechaventa            0
# fechaenrutada         0
# ruta                  0
# codigo                0
# Cantidad              0
# tipodeservicio        0
# num_ciudad            0
# nombreciudad          0
# numerozona            0
# nombrezona            0
# numerodecasa          0
# departamento        136
# num_codigopostal      0
# DCF                  10
# Calle                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Bodega                       int64
# Cedis                       object
# factura                      int64
# foliocontrol                 int64
# tienda                       int64
# Unnamed: 5                  object
# fechaventa          datetime64[ns]
# fechaenrutada       datetime64[ns]
# ruta                         int64
# codigo                       int64
# Cantidad                     int64
# tipodeservicio              object
# num_ciudad                   int64
# nombreciudad                object
# numerozona                   int64
# nombrezona                  object
# numerodecasa               float64
# departamento                object
# num_codigopostal             int64
# DCF                        float64
# Calle                       object
# dtype: object

# %% [markdown]
# ### Lista de Domicilios

# %%
f_19 = []
f_20 = []
f_21 = []
f_22 = []
f_23 = []
f_24 = []
f_25 = []
f_26 = []
f_27 = [] 
f_28 = []
f_29 = [] 
f_30 = []
f_31 = []
f_32 = []
f_33 = []
f_34 = [] 
f_36 = []
f_37 = []
f_38 = []
f_39 = []
f_40 = []
f_41 = []
f_42 = []
f_43 = []
f_44 = []

# %%
for i in range(len(df)):
    dom = f"{int(df['numerodecasa'].iloc[i])},{df['Calle'].iloc[i]},{df['nombrezona'].iloc[i]},\
    {df['num_codigopostal'].iloc[i]},{df['nombreciudad'].iloc[i]}, JALISCO, MEXICO" 
    if df['foliocontrol'].iloc[i] == 7222819: 
        f_19.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222820:
        f_20.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222821:
        f_21.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222822:
        f_22.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222823:
        f_23.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222824:
        f_24.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222825: 
        f_25.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222826:
        f_26.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222827:
        f_27.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222828: 
        f_28.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222830:
        f_30.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222831:
        f_31.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222832:
        f_32.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222833:
        f_33.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222834: 
        f_34.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222836:
        f_36.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222837: 
        f_37.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222838:
        f_38.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222839:
        f_39.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222840:
        f_40.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222841:
        f_41.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222842:
        f_42.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222843: 
        f_43.append(dom)
    elif df['foliocontrol'].iloc[i] == 7222844:
        f_44.append(dom)
    else:
        pass

# %% [markdown]
# ###  Función para la Obtención de Coordenadas con Geocoding

# %%
apikey = 'AIzaSyB-u8dReCLDNbCeQXhkJ4WydLgwbHGVaAg'

# %%
def extract_lat_long(address, data_type = 'json'):
    endpoint = f"https://maps.googleapis.com/maps/api/geocode/{data_type}"
    params = {"address": address, "key": apikey}
    url_params = urlencode(params)
    url = f"{endpoint}?{url_params}"
    r = requests.get(url)
    if r.status_code not in range(200,299):
       return {}
    latlng = {}
    try:
        latlng = r.json()['results'][0]['geometry']['location']
    except:
        pass
    return latlng.get("lat"), latlng.get("lng")

# %% [markdown]
# ### Lista de Coordenadas para cada Folio Control

# %%
c_19 = []
c_20 = []
c_21 = []
c_22 = []
c_23 = []
c_24 = []
c_25 = []
c_26 = []
c_27 = []
c_28 = []
c_30 = []
c_31 = []
c_32 = []
c_33 = []
c_34 = []
c_36 = []
c_37 = []
c_38 = []
c_39 = []
c_40 = []
c_41 = []
c_42 = []
c_43 = []
c_44 = []

# %%
def extractor(folio, lista):
    for i in range(len(folio)):
        dom = extract_lat_long(folio[i])
        lista.append(dom)

# %%
extractor(f_19, c_19)
extractor(f_20, c_20)
extractor(f_21, c_21)
extractor(f_22, c_22)
extractor(f_23, c_23)
extractor(f_24, c_24)
extractor(f_25, c_25)
extractor(f_26, c_26)
extractor(f_27, c_27)
extractor(f_28, c_28)
extractor(f_30, c_30)
extractor(f_31, c_31)
extractor(f_32, c_32)
extractor(f_33, c_33)
extractor(f_34, c_34)
extractor(f_36, c_36)
extractor(f_37, c_37)
extractor(f_38, c_38)
extractor(f_39, c_39)
extractor(f_40, c_40)
extractor(f_41, c_41)
extractor(f_42, c_42)
extractor(f_43, c_43)
extractor(f_44, c_44)

# %% [markdown]
# ### Función No Repetidos

# %%
def no_repeats(l):
    l = sorted(set(l))
    return l

# %%
nc_19 = no_repeats(c_19)
nc_20 = no_repeats(c_20)
nc_21 = no_repeats(c_21)
nc_22 = no_repeats(c_22)
nc_23 = no_repeats(c_23)
nc_24 = no_repeats(c_24)
nc_25 = no_repeats(c_25)
nc_26 = no_repeats(c_26)
nc_27 = no_repeats(c_27)
nc_28 = no_repeats(c_28)
nc_30 = no_repeats(c_30)
nc_31 = no_repeats(c_31)
nc_32 = no_repeats(c_32)
nc_33 = no_repeats(c_33)
nc_34 = no_repeats(c_34)
nc_36 = no_repeats(c_36)
nc_37 = no_repeats(c_37)
nc_38 = no_repeats(c_38)
nc_39 = no_repeats(c_39)
nc_40 = no_repeats(c_40)
nc_41 = no_repeats(c_41)
nc_42 = no_repeats(c_42)
nc_43 = no_repeats(c_43)
nc_44 = no_repeats(c_44)

# %% [markdown]
# ### Agregar Cedis a Rutas

# %%
cedis_location = [20.6489176, -103.3409776]
nc_19.append(cedis_location)
nc_20.append(cedis_location)
nc_21.append(cedis_location)
nc_22.append(cedis_location)
nc_23.append(cedis_location)
nc_24.append(cedis_location)
nc_25.append(cedis_location)
nc_26.append(cedis_location)
nc_27.append(cedis_location)
nc_28.append(cedis_location)
nc_30.append(cedis_location)
nc_31.append(cedis_location) 
nc_32.append(cedis_location)
nc_33.append(cedis_location)
nc_34.append(cedis_location)
nc_36.append(cedis_location)
nc_37.append(cedis_location)
nc_38.append(cedis_location)
nc_39.append(cedis_location)
nc_40.append(cedis_location)
nc_41.append(cedis_location)
nc_42.append(cedis_location)
nc_43.append(cedis_location)
nc_44.append(cedis_location)

# %% [markdown]
# ### Función Long_Lat

# %%
def change(l):
    return l[1], l[0]

# %%
def invertidor(l1, l2):
    for element in l1:
        volteado = change(element)
        l2.append(volteado)

# %%
longlat_19 = []
longlat_20 = []
longlat_21 = []
longlat_22 = []
longlat_23 = []
longlat_24 = []
longlat_25 = []
longlat_26 = []
longlat_27 = []
longlat_28 = []
longlat_30 = []
longlat_31 = []
longlat_32 = []
longlat_33 = []
longlat_34 = []
longlat_36 = []
longlat_37 = []
longlat_38 = []
longlat_39 = []
longlat_40 = []
longlat_41 = []
longlat_42 = []
longlat_43 = []
longlat_44 = []

# %%
invertidor(nc_19, longlat_19)
invertidor(nc_20, longlat_20)
invertidor(nc_21, longlat_21)
invertidor(nc_22, longlat_22)
invertidor(nc_23, longlat_23)
invertidor(nc_24, longlat_24)
invertidor(nc_25, longlat_25)
invertidor(nc_26, longlat_26)
invertidor(nc_27, longlat_27)
invertidor(nc_28, longlat_28)
invertidor(nc_30, longlat_30)
invertidor(nc_31, longlat_31)
invertidor(nc_32, longlat_32)
invertidor(nc_33, longlat_33)
invertidor(nc_34, longlat_34)
invertidor(nc_36, longlat_36)
invertidor(nc_37, longlat_37)
invertidor(nc_38, longlat_38)
invertidor(nc_39, longlat_39)
invertidor(nc_40, longlat_40)
invertidor(nc_41, longlat_41)
invertidor(nc_42, longlat_42)
invertidor(nc_43, longlat_43)
invertidor(nc_44, longlat_44)

# %% [markdown]
# ### Visualización de los Puntos de Entrega con respecto a Folios de Control

# %%
import folium
import openrouteservice
from openrouteservice import convert
import json

# %%
client = openrouteservice.Client(key='5b3ce3597851110001cf62481a575c2aa4e54c8d9e8e2196219e7dfc')

# %%
def guiaroji(longlat, c):
    koord = tuple(longlat)

    res = client.directions(koord)
    geometry = client.directions(koord)['routes'][0]['geometry']
    decoded = convert.decode_polyline(geometry)

    distance_txt = "<h4> <b>Distance :&nbsp" + "<strong>"+str(round(res['routes'][0]['summary']['distance']/1000,1))+" Km </strong>" +"</h4></b>"
    duration_txt = "<h4> <b>Duration :&nbsp" + "<strong>"+str(round(res['routes'][0]['summary']['duration']/60,1))+" Mins. </strong>" +"</h4></b>"


    m = folium.Map(location=[20.8, -103.3], tiles = "OpenStreetMap", zoom_start = 10)
    folium.GeoJson(decoded).add_child(folium.Popup(distance_txt+duration_txt,max_width=300)).add_to(m)

    cedis = folium.Marker(
        location = [20.6489176, -103.3409776],
        icon = folium.Icon(color = "red", icon = "home", prefix = "fa"),
        popup = f"<stong>Coppel Distribution Center</stong>",
        tooltip = f"Distribution Center")
    cedis.add_to(m)

    for i in range(len(c)):
        marker = folium.Marker(
            location = [c[i][0], c[i][1]],
            icon = folium.Icon(color = "blue", icon = 'circle', prefix = 'fa'),
            popup = f"<stong>{c[i][0]}, {c[i][1]}</stong>",
            tooltip = f"Location {i}")
        marker.add_to(m)
    return m

# %% [markdown]
# Las rutas de los camiones con folio de control con terminación 31, 34, 42.
# En la ruta 31 es debido a que el API no encuentra una ruta entre los puntos 10 y 11.
# En la ruta 34 es debido a que el API no puede graficar rutas más largas de 6000000 metros.
# En la ruta 42 no se encontró un punto parte de la ruta dentro de un radio de 350 metros del punto 1.

# %% [markdown]
# #### Mapa 19

# %%
guiaroji(longlat_19, c_19)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 20

# %%
guiaroji(longlat_20, c_20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 21

# %%
guiaroji(longlat_21, c_21)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 22

# %%
guiaroji(longlat_22, c_22)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 23

# %%
guiaroji(longlat_23, c_23)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 24

# %%
guiaroji(longlat_24, c_24)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 25

# %%
guiaroji(longlat_25, c_25)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 26

# %%
guiaroji(longlat_26, c_26)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 27

# %%
guiaroji(longlat_27, c_27)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 28

# %%
guiaroji(longlat_28, c_28)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 30

# %%
guiaroji(longlat_30, c_30)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 32

# %%
guiaroji(longlat_32, c_32)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 33

# %%
guiaroji(longlat_33, c_33)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 36

# %%
guiaroji(longlat_36, c_36)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### Mapa 37

# %%
guiaroji(longlat_37, c_37)

# %% [markdown]
# #### Mapa 38

# %%
guiaroji(longlat_38, c_38)

# %% [markdown]
# #### Mapa 39

# %%
guiaroji(longlat_39, c_39)

# %% [markdown]
# #### Mapa 40

# %%
guiaroji(longlat_40, c_40)

# %% [markdown]
# #### Mapa 41

# %%
guiaroji(longlat_41, c_41)

# %% [markdown]
# #### Mapa 43

# %%
guiaroji(longlat_43, c_43)

# %% [markdown]
# #### Mapa 44

# %%
guiaroji(longlat_44, c_44)

# %% [markdown]
# ### Revisando cuales son los valores que se repiten

# %%
print(len(c_19)+len(c_20)+len(c_21)+len(c_22)+len(c_23)+len(c_24)+len(c_25)+len(c_26)+len(c_27)+len(c_28)+len(c_36))
# Out:
# 246

# %%
print(len(nc_19)+len(nc_20)+len(nc_21)+len(nc_22)+len(nc_23)+len(nc_24)+len(nc_25)+len(nc_26)+len(nc_27)+len(nc_28)+len(nc_36)-11)
# Out:
# 184

# %%
def whichrepeat(l):    
    l1=[]
    for i in l:
        if i not in l1:
            l1.append(i)
        else:
            print(i,end='')

# %%
c_19
# Out:
# [(20.6622997, -103.2733636),
#  (20.6598636, -103.322253),
#  (20.6547544, -103.3307811),
#  (20.6550017, -103.3176626),
#  (20.651556, -103.2991682),
#  (20.6564599, -103.3013211),
#  (20.6643645, -103.3086619),
#  (20.665709, -103.3329807),
#  (20.6810216, -103.3134997),
#  (20.6668141, -103.3266607),
#  (20.6573924, -103.3140748),
#  (20.67123, -103.308009),
#  (20.6572059, -103.2905868),
#  (20.6489047, -103.2930635),
#  (20.6655958, -103.2876215),
#  (20.6432555, -103.2968284),
#  (20.6432555, -103.2968284),
#  (20.6550017, -103.3176626),
#  (20.6638026, -103.3205255),
#  (20.6653711, -103.303776),
#  (20.6433464, -103.3248323)]

# %%
whichrepeat(c_19)
# Out:
# (20.6432555, -103.2968284)(20.6550017, -103.3176626)

# %%
c_20
# Out:
# [(20.6700916, -103.273583),
#  (20.6794019, -103.274831),
#  (20.6874171, -103.2770813),
#  (20.6794019, -103.274831),
#  (20.6665263, -103.2711415),
#  (20.6665263, -103.2711415),
#  (20.6840941, -103.2710713),
#  (20.6673908, -103.2813453),
#  (20.6821749, -103.2683321),
#  (20.6700916, -103.273583),
#  (20.6653998, -103.2882011),
#  (20.6673908, -103.2813453),
#  (20.6791279, -103.2933379),
#  (20.6845195, -103.2825905),
#  (20.6821257, -103.2850096),
#  (20.67342, -103.2882529),
#  (20.6525313, -103.2805194)]

# %%
whichrepeat(c_20)
# Out:
# (20.6794019, -103.274831)(20.6665263, -103.2711415)(20.6700916, -103.273583)(20.6673908, -103.2813453)

# %%
c_21
# Out:
# [(20.7160767, -103.3150292),
#  (20.7160767, -103.3150292),
#  (20.6978123, -103.2784999),
#  (20.7160767, -103.3150292),
#  (20.7160767, -103.3150292),
#  (20.7037164, -103.29088),
#  (20.7160767, -103.3150292),
#  (20.7009675, -103.306387),
#  (20.7038253, -103.2966416),
#  (20.7160767, -103.3150292),
#  (20.7038253, -103.2966416),
#  (20.7038253, -103.2966416),
#  (20.6978123, -103.2784999),
#  (20.7038253, -103.2966416),
#  (20.708112, -103.2999399),
#  (20.7038253, -103.2966416),
#  (20.6978123, -103.2784999),
#  (20.6994258, -103.3031519),
#  (20.7038253, -103.2966416),
#  (20.6838375, -103.2859276),
#  (20.7080023, -103.288749),
#  (20.7160767, -103.3150292),
#  (20.6838375, -103.2859276),
#  (20.6854059, -103.2763723)]

# %%
whichrepeat(c_21)
# Out:
#  (20.6080837, -103.346261),
#  (20.6581658, -103.3937987),
#  (20.6300617, -103.3768475),
#  (20.6254755, -103.412596),
#  (20.7061029, -103.3855806),
#  (20.8089354, -103.4574849),
#  (20.7192784, -103.3957248),
#  (20.7253884, -103.3492),
#  (20.7038023, -103.3485767),
#  (20.6970445, -103.3226457),
#  (20.6323766, -103.376688),
#  (20.6187582, -103.3730902),
#  (20.6970445, -103.3226457),
#  (20.6307498, -103.4244242),
#  (20.7346968, -103.4078415),
#  (20.6607912, -103.3717197),
#  (20.6254755, -103.412596),
#  (20.7889956, -103.4424922),
#  (20.6312166, -103.3767972),
#  (20.6079605, -103.3457224),
# ...

# %%
whichrepeat(c_28)
# Out:
# (20.6254755, -103.412596)(20.6970445, -103.3226457)(20.6254755, -103.412596)(20.6191431, -103.3867487)(20.6323766, -103.376688)(20.6312166, -103.3767972)(20.7038023, -103.3485767)(20.7107557, -103.3324466)(20.7192784, -103.3957248)(20.7697391, -103.4462887)

# %%
c_36
# Out:
# [(20.6788253, -103.3590221),
#  (20.6948976, -103.3495616),
#  (20.6786855, -103.3541445),
#  (20.6977871, -103.379979),
#  (20.672663, -103.3315879),
#  (20.7390641, -103.3464424),
#  (20.6729508, -103.3313729),
#  (20.7302403, -103.3773188),
#  (20.6750468, -103.3558794),
#  (20.665741, -103.29088),
#  (20.6749979, -103.3484478),
#  (20.6788253, -103.3590221),
#  (20.6959956, -103.3444142),
#  (20.6804322, -103.3343515),
#  (20.6855548, -103.341876),
#  (20.6804322, -103.3343515),
#  (20.6804322, -103.3343515),
#  (20.6854669, -103.3685888),
#  (20.6948976, -103.3495616),
#  (20.6749979, -103.3484478),
#  (20.6712713, -103.3335632)]

# %%
whichrepeat(c_36)
# Out:
# (20.6788253, -103.3590221)(20.6804322, -103.3343515)(20.6804322, -103.3343515)(20.6948976, -103.3495616)(20.6749979, -103.3484478)

# %%
domicilios = []
for i in range(len(df)):
    dom = f"{int(df['numerodecasa'].iloc[i])},{df['Calle'].iloc[i]},{df['nombrezona'].iloc[i]},\
    {df['num_codigopostal'].iloc[i]},{df['nombreciudad'].iloc[i]}, JALISCO, MEXICO"
    domicilios.append(dom)

# %%
koordinaten = []
extractor(domicilios, koordinaten)

# %%
m = folium.Map(location=[20.8, -103.3], tiles = "OpenStreetMap", zoom_start = 10)
cedis = folium.Marker(
    location = [20.6489176, -103.3409776],
    icon = folium.Icon(color = "red", icon = "home", prefix = "fa"),
    popup = f"<stong>Coppel Distribution Center</stong>",
    tooltip = f"Distribution Center")
cedis.add_to(m)

for i in range(len(koordinaten)):
    marker = folium.Marker(
        location = [koordinaten[i][0], koordinaten[i][1]],
        icon = folium.Icon(color = "blue", icon = 'circle', prefix = 'fa'),
        popup = f"<stong>{koordinaten[i][0]}, {koordinaten[i][1]}</stong>",
        tooltip = f"Location {i}")
    marker.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

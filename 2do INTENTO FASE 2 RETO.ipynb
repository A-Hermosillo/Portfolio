# %%
# Import packages
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm

# %%
# Read the National Coronavirus Dataset
df_N = pd.read_csv('211016COVID19MEXICO.csv')
# Out:
# /Users/axhermosillo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_N.groupby(['TABAQUISMO']).count()
# Out:
#             FECHA_ACTUALIZACION  ID_REGISTRO    ORIGEN    SECTOR  ENTIDAD_UM  \
# TABAQUISMO
# 1                        791476       791476    791476    791476      791476
# 2                      10245436     10245436  10245436  10245436    10245436
# 98                        25752        25752     25752     25752       25752
#
#                 SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# TABAQUISMO
# 1             791476       791476       791476         791476         791476
# 2           10245436     10245436     10245436       10245436       10245436
# 98             25752        25752        25752          25752          25752
#
#             ...  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# TABAQUISMO  ...
# 1           ...     791476            791476         791476
# 2           ...   10245436          10245436       10245436
# 98          ...      25752             25752          25752
#
# ...

# %%
df_N.groupby(['OBESIDAD']).count()
# Out:
#           FECHA_ACTUALIZACION  ID_REGISTRO   ORIGEN   SECTOR  ENTIDAD_UM  \
# OBESIDAD
# 1                     1097427      1097427  1097427  1097427     1097427
# 2                     9941199      9941199  9941199  9941199     9941199
# 98                      24038        24038    24038    24038       24038
#
#              SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# OBESIDAD
# 1         1097427      1097427      1097427        1097427        1097427
# 2         9941199      9941199      9941199        9941199        9941199
# 98          24038        24038        24038          24038          24038
#
#           ...  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# OBESIDAD  ...
# 1         ...    1097427           1097427        1097427
# 2         ...    9941199           9941199        9941199
# 98        ...      24038             24038          24038
#
#           TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  \
# OBESIDAD
# ...

# %%
df_N.groupby(['SEXO','TABAQUISMO']).count()
# Out:
#                  FECHA_ACTUALIZACION  ID_REGISTRO   ORIGEN   SECTOR  \
# SEXO TABAQUISMO
# 1    1                        285111       285111   285111   285111
#      2                       5507606      5507606  5507606  5507606
#      98                         8496         8496     8496     8496
# 2    1                        506365       506365   506365   506365
#      2                       4737830      4737830  4737830  4737830
#      98                        17256        17256    17256    17256
#
#                  ENTIDAD_UM  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  \
# SEXO TABAQUISMO
# 1    1               285111       285111       285111         285111
#      2              5507606      5507606      5507606        5507606
#      98                8496         8496         8496           8496
# 2    1               506365       506365       506365         506365
#      2              4737830      4737830      4737830        4737830
# ...

# %%
df_N.groupby(['SEXO','OBESIDAD']).count()
# Out:
#                FECHA_ACTUALIZACION  ID_REGISTRO   ORIGEN   SECTOR  ENTIDAD_UM  \
# SEXO OBESIDAD
# 1    1                      615943       615943   615943   615943      615943
#      2                     5177453      5177453  5177453  5177453     5177453
#      98                       7817         7817     7817     7817        7817
# 2    1                      481484       481484   481484   481484      481484
#      2                     4763746      4763746  4763746  4763746     4763746
#      98                      16221        16221    16221    16221       16221
#
#                ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# SEXO OBESIDAD
# 1    1              615943       615943         615943         615943
#      2             5177453      5177453        5177453        5177453
#      98               7817         7817           7817           7817
# 2    1              481484       481484         481484         481484
# ...

# %%
df_NM = df_N[df_N['FECHA_DEF'] != '9999-99-99']

# %%
df_NM.head()
# Out:
#     FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 1            2021-10-16      z49a69       1      12          23     1
# 39           2021-10-16      z1da2d       1      12           2     1
# 61           2021-10-16      z4e838       1      12           9     2
# 152          2021-10-16      1236ca       1       3          15     2
# 174          2021-10-16      12914d       1      12          32     1
#
#      ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 1             23           23              4              2  ...         1
# 39             2            2              4              2  ...        99
# 61            15           15             95              2  ...        99
# 152           15           15             60              2  ...         2
# 174           32           32             56              2  ...         2
#
#     TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# ...

# %%
df_NM.groupby(['TABAQUISMO']).count()
# Out:
#             FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# TABAQUISMO
# 1                         28291        28291   28291   28291       28291
# 2                        332620       332620  332620  332620      332620
# 98                         2156         2156    2156    2156        2156
#
#               SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# TABAQUISMO
# 1            28291        28291        28291          28291          28291
# 2           332620       332620       332620         332620         332620
# 98            2156         2156         2156           2156           2156
#
#             ...  OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  \
# TABAQUISMO  ...
# 1           ...      28291             28291          28291
# 2           ...     332620            332620         332620
# 98          ...       2156              2156           2156
#
#             TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  CLASIFICACION_FINAL  \
# ...

# %%
df_NM.groupby(['OBESIDAD']).count()
# Out:
#           FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# OBESIDAD
# 1                       73144        73144   73144   73144       73144
# 2                      288063       288063  288063  288063      288063
# 98                       1860         1860    1860    1860        1860
#
#             SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# OBESIDAD                                                                  ...
# 1          73144        73144        73144          73144          73144  ...
# 2         288063       288063       288063         288063         288063  ...
# 98          1860         1860         1860           1860           1860  ...
#
#           OTRO_CASO  TOMA_MUESTRA_LAB  RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# OBESIDAD
# 1             73144             73144          73144                  73144
# 2            288063            288063         288063                 288063
# ...

# %%
df_NM.groupby(['SEXO','TABAQUISMO']).count()
# Out:
#                  FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# SEXO TABAQUISMO
# 1    1                          5357         5357    5357    5357        5357
#      2                        134026       134026  134026  134026      134026
#      98                          710          710     710     710         710
# 2    1                         22934        22934   22934   22934       22934
#      2                        198594       198594  198594  198594      198594
#      98                         1446         1446    1446    1446        1446
#
#                  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# SEXO TABAQUISMO
# 1    1                  5357         5357           5357           5357
#      2                134026       134026         134026         134026
#      98                  710          710            710            710
# 2    1                 22934        22934          22934          22934
# ...

# %%
df_NM.groupby(['SEXO','OBESIDAD']).count()
# Out:
#                FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# SEXO OBESIDAD
# 1    1                       33434        33434   33434   33434       33434
#      2                      106032       106032  106032  106032      106032
#      98                        627          627     627     627         627
# 2    1                       39710        39710   39710   39710       39710
#      2                      182031       182031  182031  182031      182031
#      98                       1233         1233    1233    1233        1233
#
#                ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  \
# SEXO OBESIDAD
# 1    1               33434        33434          33434          33434
#      2              106032       106032         106032         106032
#      98                627          627            627            627
# 2    1               39710        39710          39710          39710
# ...

# %%
# Confidence Interval Mujeres Obesidad 95
sm.stats.proportion_confint(33434,615943)
# Out:
# (0.05371517091814805, 0.05484682264294445)

# %%
# Confidence Interval Mujeres Sin Obesidad 95
sm.stats.proportion_confint(106032,5177453)
# Out:
# (0.020357568601690967, 0.020601567096885147)

# %%
# Confidence Interval Hombres Obesidad 95
sm.stats.proportion_confint(39710,481484)
# Out:
# (0.0816971762839803, 0.08325119167840267)

# %%
# Confidence Interval Hombres Sin Obesidad 95
sm.stats.proportion_confint(182031,4763746)
# Out:
# (0.03803958311564103, 0.0383838869854097)

# %%
# Confidence Interval Mujeres Fumadores 95
sm.stats.proportion_confint(5357,285111)
# Out:
# (0.018290775550961022, 0.01928757112805171)

# %%
# Confidence Interval Mujeres No Fumadores 95
sm.stats.proportion_confint(134026,5507606)
# Out:
# (0.024206025275154634, 0.02446339661159616)

# %%
# Confidence Interval Hombres Fumadores 95
sm.stats.proportion_confint(22934,506365)
# Out:
# (0.04471869705649446, 0.045864182881889905)

# %%
# Confidence Interval Hombres No Fumadores 95
sm.stats.proportion_confint(198594,4737830)
# Out:
# (0.041736209528392416, 0.04209710656779508)

# %%
# Confidence Interval Obesidad Total 95
sm.stats.proportion_confint(73144,1097427)
# Out:
# (0.06618380475791989, 0.06711708906007437)

# %%
# Confidence Interval Sin Obesidad Total 95
sm.stats.proportion_confint(288063,9941199)
# Out:
# (0.02887241376503418, 0.02908095785543132)

# %%
# Confidence Interval Tabaquismo Total 95
sm.stats.proportion_confint(28291,791476)
# Out:
# (0.03533560200731992, 0.036153615606353766)

# %%
# Confidence Interval No Tabaquismo Total 95
sm.stats.proportion_confint(332620,10245436)
# Out:
# (0.03235666359250238, 0.032573711259285286)

# %%
# GRAFICAS

# set width of bars
barWidth = 0.25
 
# set heights of bars
bars1 = [39710, 22934]
bars2 = [33434, 5357]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

# Make the plot
plt.bar(r1, bars1, color='#7400ff', width=barWidth, edgecolor='black', label='Hombres')
plt.bar(r2, bars2, color='#ffc900', width=barWidth, edgecolor='black', label='Mujeres')
 
# Add xticks on the middle of the group bars
plt.xlabel('Cantidad de muertes', fontweight='bold', color = 'black')
plt.xticks([r + barWidth for r in range(len(bars1))], ['Obesidad', 'Tabaquismo'], color ='black')
plt.ylabel('Personas', fontweight='bold', color = 'black')
#plt.yticks(color = 'white')
# Create legend & Show graphic
plt.legend()
plt.show()

# %%
# set width of bars
barWidth = 0.25
 
# set heights of bars
bars1 = [5.428, 1.879, 8.247, 4.529, 6.665, 3.574]
bars2 = [2.047, 2.433, 3.821, 4.191, 2.897, 3.247]
bars3 = bars1 + bars2

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = r1 + r2
 
# Make the plot
plt.bar(r1, bars1, color='#7400ff', width=barWidth, edgecolor='black', label='Si')
plt.bar(r2, bars2, color='#ffc900', width=barWidth, edgecolor='black', label='No')
 
plt.legend()


# Add xticks on the middle of the group bars
plt.xticks([r + barWidth for r in range(len(bars1))], ['Mo', 'Mf', 'Ho', 'Hf', 'To','Tf'])

plt.xlabel('Categorías', fontweight='bold')
plt.ylabel('Proporción de mortalidad', fontweight='bold')

# Create legend & Show graphic
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(range(10))
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

ax.spines['bottom'].set_color('purple')
ax.spines['top'].set_color('purple')
ax.spines['left'].set_color('purple')
ax.spines['right'].set_color('purple')
ax.xaxis.label.set_color('red')
ax.tick_params(axis='x', colors='red')

plt.show()

# %%
# import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# set plot style: grey grid in the background:
sns.set(style="darkgrid")

# load dataset
df_N = pd.read_csv('211016COVID19MEXICO.csv')
# Out:
# /Users/axhermosillo/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-eb56ae3b21d8> in <module>
#      13
#      14 # grouped barplot
# ---> 15 sns.barplot(x="SEXO", y="TABAQUISMO", hue="TABAQUISMO", data=tips, ci=None);
#
# NameError: name 'tips' is not defined

# %%
 #Set the figure size
plt.figure(figsize=(8, 8))

# grouped barplot
sns.barplot(x="SEXO", y="TABAQUISMO", hue="TABAQUISMO", data=, ci=None);
